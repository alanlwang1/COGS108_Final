# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Ant Man
# - Hulk
# - Iron Man
# - Thor
# - Wasp

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# According to Gallup’s World Happiness report’s dataset, which of the six measurements (GDP per capita, healthy life expectancy, social support, freedom to make life choices, generosity, corruption perception) most strongly predicts happiness across the countries surveyed ?:
#
# - What indicator displays the largest difference in life satisfaction between the top 15% of the countries and the bottom 15% of the countries, in terms of the indicators of happiness?
# - Which feature overall is the most strongly correlated with life satisfaction up to 2021?
# - Which feature overall is the most strongly correlated with positive affect up to 2020?

# %% [markdown]
# # Setup

# %%
# Importing necessary libraries to use during the cleaning as well as the analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Preparing the csv files
df1 = pd.read_csv('./DataForFigure2.1WHR2021C2.csv')
df2 = pd.read_csv('./DataPanelWHR2021C2.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %% [markdown]
# For our first and second question, we want the Gallup World Health Report to include all years upto 2021. Therefore, we need to combine both the data from 2021 and the data from earlier years into one.
#
# After reading in both our csv datasets-df1 and df2- we proceeded to first clean df1 by selecting and renaming the columns and or categories we deemed essential to our research question for better formatting. To clean up df2, we renamed the columns we needed here as well to match them with the columns of df1. Moving on, both data frames were then concatenated, or linked and sorted by alphabetical order by country. We then used the dataframe.pop() method to remove columns that wouldn’t be relevant. Lastly, after manipulating and filtering these dataframes, we proceeded to reset the indices to make our data sequential. Our data is now in a usable format.
#
# For our third question, because the 2021's data does not include the data for positive affect and negative affect, we use the data from earlier years and leave as is.
#
# Apart from importing the necessary library packages and dataset and taking steps to clean and manipulate our datasets, there were no other pre-processing steps done.

# %%
# Cleaning up df1: Picking necessary columns, renaming the columns, inserting a column for proper concatenation
df1 = df1[['Country name', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
df1.columns = ['country_name', 'ladder_score', 'GDP', 'social_support', 'life_expectancy', 'choice_freedom', 'generosity', 'corr_perception']
df1.insert(loc=1, column='year', value=2021)

# Cleaning up df2: Renaming the columns
df2.columns = ['country_name', 'year', 'ladder_score', 'GDP', 'social_support', 'life_expectancy', 'choice_freedom', 'generosity', 'corr_perception', 'pos_affect', 'neg_affect']

# %%
# Concatenating the two data frames: First concatenate, sort by name and year, pop unnecessary columns, reset the indices
df1 = pd.concat([df1, df2])
df1 = df1.sort_values(['country_name', 'year'], ascending = True)
df1.pop('pos_affect')
df1.pop('neg_affect')
df1.reset_index(drop=True)
# Out:
#      country_name  year  ladder_score    GDP  social_support  life_expectancy  \
# 0     Afghanistan  2008         3.724  7.370           0.451           50.800
# 1     Afghanistan  2009         4.402  7.540           0.552           51.200
# 2     Afghanistan  2010         4.758  7.647           0.539           51.600
# 3     Afghanistan  2011         3.832  7.620           0.521           51.920
# 4     Afghanistan  2012         3.783  7.705           0.521           52.240
# ...           ...   ...           ...    ...             ...              ...
# 2093     Zimbabwe  2017         3.638  8.016           0.754           55.000
# 2094     Zimbabwe  2018         3.616  8.049           0.775           55.600
# 2095     Zimbabwe  2019         2.694  7.950           0.759           56.200
# 2096     Zimbabwe  2020         3.160  7.829           0.717           56.800
# 2097     Zimbabwe  2021         3.145  7.943           0.750           56.201
#
#       choice_freedom  generosity  corr_perception
# 0              0.718       0.168            0.882
# 1              0.679       0.190            0.850
# 2              0.600       0.121            0.707
# 3              0.496       0.162            0.731
# 4              0.531       0.236            0.776
# ...              ...         ...              ...
# 2093           0.753      -0.098            0.751
# 2094           0.763      -0.068            0.844
# 2095           0.632      -0.064            0.831
# 2096           0.643      -0.009            0.789
# 2097           0.677      -0.047            0.821
#
# [2098 rows x 9 columns]

# %%
# Drop all the rows with any NaN columns
df1.dropna(subset = ['ladder_score', 'GDP', 'social_support', 'life_expectancy', 'choice_freedom', 'generosity', 'corr_perception'], inplace = True)
df2.dropna(subset = ['ladder_score', 'GDP', 'social_support', 'life_expectancy', 'choice_freedom', 'generosity', 'corr_perception', 'pos_affect'], inplace = True)

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True)
sns.set_palette("flare")
sns.histplot(df1['generosity'], ax=ax1, kde=False, bins=30)
ax1.set_title('generosity')
ax1.set_xlabel('')
sns.histplot(df1['corr_perception'], ax=ax2, kde=False, bins=30)
ax2.set_title('corr_perception')
ax2.set_xlabel('')
sns.histplot(df1['ladder_score'], ax=ax3, kde=False, bins=30)
ax3.set_title('ladder_score')
ax3.set_xlabel('')
fig.set_figwidth(20)

# %% [markdown]
# We first want to see the distributions of each variable visually to spot any skewness for possible outliers that may exist (within df1).

# %%
q1 = df1['generosity'].quantile(.25)
q3 = df1['generosity'].quantile(.75)

iqr = q3 - q1

upper = df1[df1['generosity'] > q3 + (1.5 * iqr)]
lower = df1[df1['generosity'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
#       country_name  year  ladder_score     GDP  social_support  \
# 0         Cambodia  2011         4.161   7.960           0.716
# 1           Gambia  2018         4.922   7.671           0.685
# 2           Gambia  2019         5.164   7.699           0.694
# 3           Gambia  2021         5.051   7.686           0.690
# 4            Haiti  2006         3.754   7.407           0.694
# 5            Haiti  2018         3.615   7.477           0.538
# 6            Haiti  2021         3.615   7.477           0.540
# 7        Indonesia  2010         5.457   9.022           0.816
# 8        Indonesia  2011         5.173   9.069           0.825
# 9        Indonesia  2014         5.597   9.190           0.905
# 10       Indonesia  2015         5.043   9.225           0.809
# 11       Indonesia  2016         5.136   9.262           0.792
# 12       Indonesia  2017         5.098   9.300           0.796
# 13       Indonesia  2018         5.340   9.339           0.809
# 14       Indonesia  2019         5.347   9.377           0.802
# 15       Indonesia  2021         5.345   9.365           0.811
# 16            Laos  2006         5.076   8.251           0.807
# 17            Laos  2007         5.364   8.307           0.790
# 18            Laos  2008         5.044   8.366           0.807
# 19            Laos  2011         4.704   8.548           0.691
# 20           Malta  2014         6.452  10.486           0.941
# 21         Myanmar  2012         4.439   8.158           0.612
# 22         Myanmar  2013         4.176   8.230           0.757
# 23         Myanmar  2015         4.224   8.359           0.752
# 24         Myanmar  2016         4.623   8.408           0.793
# 25         Myanmar  2017         4.154   8.464           0.795
# 26         Myanmar  2018         4.411   8.523           0.774
# 27         Myanmar  2019         4.434   8.545           0.763
# 28         Myanmar  2020         4.431   8.554           0.796
# 29         Myanmar  2021         4.426   8.541           0.779
# 30        Thailand  2007         5.784   9.508           0.889
# 31        Thailand  2008         5.636   9.520           0.832
# 32        Thailand  2009         5.476   9.508           0.893
# 33        Thailand  2010         6.217   9.576           0.898
# 34        Thailand  2011         6.664   9.579           0.884
# 35        Thailand  2013         6.231   9.667           0.926
# 36        Thailand  2014         6.985   9.672           0.933
# 37  United Kingdom  2010         7.029  10.649           0.955
#
#     life_expectancy  choice_freedom  generosity  corr_perception
# 0            58.880           0.927       0.418            0.775
# 1            55.000           0.719       0.440            0.691
# 2            55.300           0.677       0.410            0.798
# 3            55.160           0.697       0.424            0.746
# 4            48.460           0.449       0.401            0.854
# 5            55.700           0.591       0.422            0.720
# 6            55.700           0.593       0.422            0.721
# 7            60.400           0.700       0.448            0.954
# 8            60.620           0.878       0.438            0.962
# 9            61.280           0.719       0.408            0.970
# 10           61.500           0.779       0.471            0.946
# 11           61.700           0.830       0.500            0.890
# 12           61.900           0.865       0.488            0.900
# 13           62.100           0.879       0.512            0.868
# 14           62.300           0.866       0.555            0.861
# 15           62.236           0.873       0.542            0.867
# 16           53.920           0.925       0.439            0.688
# 17           54.440           0.867       0.478            0.580
# 18           54.960           0.886       0.416            0.637
# 19           56.300           0.882       0.459            0.587
# 20           72.080           0.904       0.404            0.670
# 21           57.020           0.691       0.645            0.695
# 22           57.380           0.775       0.689            0.638
# 23           58.100           0.808       0.688            0.633
# 24           58.400           0.877       0.679            0.607
# 25           58.700           0.886       0.650            0.619
# 26           59.000           0.906       0.490            0.647
# 27           59.300           0.899       0.561            0.682
# 28           59.600           0.825       0.470            0.647
# 29           59.302           0.876       0.509            0.660
# 30           64.480           0.870       0.391            0.898
# 31           64.820           0.868       0.425            0.933
# 32           65.160           0.868       0.525            0.904
# 33           65.500           0.860       0.536            0.917
# 34           65.720           0.927       0.400            0.923
# 35           66.160           0.781       0.456            0.925
# 36           66.380           0.900       0.553            0.920
# 37           71.300           0.841       0.403            0.587

# %% [markdown]
# There are 37 rows with generosity outliers using the IQR method.

# %%
q1 = df1['corr_perception'].quantile(.25)
q3 = df1['corr_perception'].quantile(.75)

iqr = q3 - q1

upper = df1[df1['corr_perception'] > q3 + (1.5 * iqr)]
lower = df1[df1['corr_perception'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
#              country_name  year  ladder_score     GDP  social_support  \
# 0               Australia  2010         7.450  10.722           0.955
# 1               Australia  2011         7.406  10.733           0.967
# 2               Australia  2012         7.196  10.754           0.945
# 3               Australia  2015         7.309  10.779           0.952
# 4               Australia  2016         7.250  10.791           0.942
# ..                    ...   ...           ...     ...             ...
# 162  United Arab Emirates  2009         6.866  10.975           0.885
# 163  United Arab Emirates  2010         7.097  10.914           0.912
# 164        United Kingdom  2012         6.881  10.664           0.935
# 165        United Kingdom  2017         7.103  10.736           0.937
# 166        United Kingdom  2018         7.233  10.743           0.928
#
#      life_expectancy  choice_freedom  generosity  corr_perception
# 0              72.20           0.932       0.317            0.366
# 1              72.30           0.945       0.369            0.382
# 2              72.40           0.935       0.274            0.368
# 3              72.70           0.922       0.332            0.357
# 4              73.00           0.922       0.239            0.399
# ..               ...             ...         ...              ...
# 162            66.28           0.849       0.019            0.339
# 163            66.40           0.878       0.057            0.355
# 164            71.46           0.889       0.371            0.425
# 165            72.10           0.813       0.291            0.419
# 166            72.30           0.838       0.226            0.404
#
# [167 rows x 9 columns]

# %% [markdown]
# There are 167 rows with corr_perception outliers using the IQR method.

# %%
q1 = df1['ladder_score'].quantile(.25)
q3 = df1['ladder_score'].quantile(.75)

iqr = q3 - q1

upper = df1[df1['ladder_score'] > q3 + (1.5 * iqr)]
lower = df1[df1['ladder_score'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
# Empty DataFrame
# Columns: [country_name, year, ladder_score, GDP, social_support, life_expectancy, choice_freedom, generosity, corr_perception]
# Index: []

# %% [markdown]
# There are no ladder_score outliers using the IQR method.

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, sharey=True)
sns.set_palette("flare")
sns.histplot(df2['generosity'], ax=ax1, kde=False, bins=30)
ax1.set_title('generosity')
ax1.set_xlabel('')
sns.histplot(df2['corr_perception'], ax=ax2, kde=False, bins=30)
ax2.set_title('corr_perception')
ax2.set_xlabel('')
sns.histplot(df2['ladder_score'], ax=ax3, kde=False, bins=30)
ax3.set_title('ladder_score')
ax3.set_xlabel('')
sns.histplot(df2['pos_affect'], ax=ax4, kde=False, bins=30)
ax4.set_title('pos_affect')
ax4.set_xlabel('')
fig.set_figwidth(20)

# %% [markdown]
# We first want to see the distributions of each variable visually to spot any skewness for possible outliers that may exist (within df2).

# %%
q1 = df2['generosity'].quantile(.25)
q3 = df2['generosity'].quantile(.75)

iqr = q3 - q1

upper = df2[df2['generosity'] > q3 + (1.5 * iqr)]
lower = df2[df2['generosity'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
#       country_name  year  ladder_score     GDP  social_support  \
# 0         Cambodia  2011         4.161   7.960           0.716
# 1           Gambia  2018         4.922   7.671           0.685
# 2           Gambia  2019         5.164   7.699           0.694
# 3            Haiti  2006         3.754   7.407           0.694
# 4            Haiti  2018         3.615   7.477           0.538
# 5        Indonesia  2010         5.457   9.022           0.816
# 6        Indonesia  2011         5.173   9.069           0.825
# 7        Indonesia  2014         5.597   9.190           0.905
# 8        Indonesia  2015         5.043   9.225           0.809
# 9        Indonesia  2016         5.136   9.262           0.792
# 10       Indonesia  2017         5.098   9.300           0.796
# 11       Indonesia  2018         5.340   9.339           0.809
# 12       Indonesia  2019         5.347   9.377           0.802
# 13            Laos  2006         5.076   8.251           0.807
# 14            Laos  2007         5.364   8.307           0.790
# 15            Laos  2008         5.044   8.366           0.807
# 16            Laos  2011         4.704   8.548           0.691
# 17           Malta  2014         6.452  10.486           0.941
# 18         Myanmar  2012         4.439   8.158           0.612
# 19         Myanmar  2013         4.176   8.230           0.757
# 20         Myanmar  2015         4.224   8.359           0.752
# 21         Myanmar  2016         4.623   8.408           0.793
# 22         Myanmar  2017         4.154   8.464           0.795
# 23         Myanmar  2018         4.411   8.523           0.774
# 24         Myanmar  2019         4.434   8.545           0.763
# 25         Myanmar  2020         4.431   8.554           0.796
# 26        Thailand  2007         5.784   9.508           0.889
# 27        Thailand  2008         5.636   9.520           0.832
# 28        Thailand  2009         5.476   9.508           0.893
# 29        Thailand  2010         6.217   9.576           0.898
# 30        Thailand  2011         6.664   9.579           0.884
# 31        Thailand  2013         6.231   9.667           0.926
# 32        Thailand  2014         6.985   9.672           0.933
# 33  United Kingdom  2010         7.029  10.649           0.955
#
#     life_expectancy  choice_freedom  generosity  corr_perception  pos_affect  \
# 0             58.88           0.927       0.418            0.775       0.799
# 1             55.00           0.719       0.440            0.691       0.804
# 2             55.30           0.677       0.410            0.798       0.773
# 3             48.46           0.449       0.401            0.854       0.613
# 4             55.70           0.591       0.422            0.720       0.584
# 5             60.40           0.700       0.448            0.954       0.837
# 6             60.62           0.878       0.438            0.962       0.864
# 7             61.28           0.719       0.408            0.970       0.852
# 8             61.50           0.779       0.471            0.946       0.876
# 9             61.70           0.830       0.500            0.890       0.833
# 10            61.90           0.865       0.488            0.900       0.863
# 11            62.10           0.879       0.512            0.868       0.864
# 12            62.30           0.866       0.555            0.861       0.877
# 13            53.92           0.925       0.439            0.688       0.886
# 14            54.44           0.867       0.478            0.580       0.861
# 15            54.96           0.886       0.416            0.637       0.829
# 16            56.30           0.882       0.459            0.587       0.900
# 17            72.08           0.904       0.404            0.670       0.652
# 18            57.02           0.691       0.645            0.695       0.764
# 19            57.38           0.775       0.689            0.638       0.803
# 20            58.10           0.808       0.688            0.633       0.866
# 21            58.40           0.877       0.679            0.607       0.804
# 22            58.70           0.886       0.650            0.619       0.746
# 23            59.00           0.906       0.490            0.647       0.777
# 24            59.30           0.899       0.561            0.682       0.755
# 25            59.60           0.825       0.470            0.647       0.800
# 26            64.48           0.870       0.391            0.898       0.832
# 27            64.82           0.868       0.425            0.933       0.819
# 28            65.16           0.868       0.525            0.904       0.898
# 29            65.50           0.860       0.536            0.917       0.901
# 30            65.72           0.927       0.400            0.923       0.934
# 31            66.16           0.781       0.456            0.925       0.846
# 32            66.38           0.900       0.553            0.920       0.811
# 33            71.30           0.841       0.403            0.587       0.863
#
#     neg_affect
# 0        0.308
# 1        0.379
# 2        0.401
# 3        0.332
# 4        0.359
# 5        0.218
# 6        0.273
# 7        0.242
# 8        0.274
# 9        0.342
# 10       0.319
# 11       0.296
# 12       0.302
# 13       0.163
# 14       0.136
# 15       0.202
# 16       0.225
# 17       0.352
# 18       0.205
# 19       0.217
# 20       0.272
# 21       0.302
# 22       0.282
# 23       0.300
# 24       0.286
# 25       0.289
# 26       0.180
# 27       0.145
# 28       0.166
# 29       0.182
# 30       0.117
# 31       0.141
# 32       0.169
# 33       0.176

# %% [markdown]
# There are 33 rows with generosity outliers using the IQR method.

# %%
q1 = df2['corr_perception'].quantile(.25)
q3 = df2['corr_perception'].quantile(.75)

iqr = q3 - q1

upper = df2[df2['corr_perception'] > q3 + (1.5 * iqr)]
lower = df2[df2['corr_perception'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
#              country_name  year  ladder_score     GDP  social_support  \
# 0               Australia  2010         7.450  10.722           0.955
# 1               Australia  2011         7.406  10.733           0.967
# 2               Australia  2012         7.196  10.754           0.945
# 3               Australia  2015         7.309  10.779           0.952
# 4               Australia  2016         7.250  10.791           0.942
# ..                    ...   ...           ...     ...             ...
# 148  United Arab Emirates  2009         6.866  10.975           0.885
# 149  United Arab Emirates  2010         7.097  10.914           0.912
# 150        United Kingdom  2012         6.881  10.664           0.935
# 151        United Kingdom  2017         7.103  10.736           0.937
# 152        United Kingdom  2018         7.233  10.743           0.928
#
#      life_expectancy  choice_freedom  generosity  corr_perception  pos_affect  \
# 0              72.20           0.932       0.317            0.366       0.834
# 1              72.30           0.945       0.369            0.382       0.816
# 2              72.40           0.935       0.274            0.368       0.811
# 3              72.70           0.922       0.332            0.357       0.790
# 4              73.00           0.922       0.239            0.399       0.791
# ..               ...             ...         ...              ...         ...
# 148            66.28           0.849       0.019            0.339       0.770
# 149            66.40           0.878       0.057            0.355       0.763
# 150            71.46           0.889       0.371            0.425       0.844
# 151            72.10           0.813       0.291            0.419       0.759
# 152            72.30           0.838       0.226            0.404       0.783
#
#      neg_affect
# 0         0.220
# 1         0.195
# 2         0.214
# 3         0.210
# 4         0.236
# ..          ...
# 148       0.287
# 149       0.233
# 150       0.184
# 151       0.210
# 152       0.228
#
# [153 rows x 11 columns]

# %% [markdown]
# There are 153 rows with corr_perception outliers using the IQR method.

# %%
q1 = df2['ladder_score'].quantile(.25)
q3 = df2['ladder_score'].quantile(.75)

iqr = q3 - q1

upper = df2[df2['ladder_score'] > q3 + (1.5 * iqr)]
lower = df2[df2['ladder_score'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
# Empty DataFrame
# Columns: [country_name, year, ladder_score, GDP, social_support, life_expectancy, choice_freedom, generosity, corr_perception, pos_affect, neg_affect]
# Index: []

# %% [markdown]
# There are no ladder_score outliers using the IQR method.

# %%
q1 = df2['pos_affect'].quantile(.25)
q3 = df2['pos_affect'].quantile(.75)

iqr = q3 - q1

upper = df2[df2['pos_affect'] > q3 + (1.5 * iqr)]
lower = df2[df2['pos_affect'] < q1 - (1.5 * iqr)] 
outliers = pd.concat([upper, lower], ignore_index=True, sort=False)
outliers
# Out:
#   country_name  year  ladder_score    GDP  social_support  life_expectancy  \
# 0  Afghanistan  2019         2.375  7.697           0.420             52.4
# 1      Lebanon  2019         4.024  9.597           0.866             67.6
#
#    choice_freedom  generosity  corr_perception  pos_affect  neg_affect
# 0           0.394      -0.108            0.924       0.351       0.502
# 1           0.447      -0.081            0.890       0.322       0.494

# %% [markdown]
# There are two rows with pos_affect outliers using the IQR method.
